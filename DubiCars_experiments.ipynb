# %%
import requests

# %%
page = 1
data = requests.get('https://www.dubicars.com/search?o=&did=&gen=&ul=RU&ma=13&mo=0&b=&set=bu&eo=export-only&stsd=&cr=USD&cy=&co=&s=&gi=&f=&g=&l=&st=&page='+str(page))

# %%
data.content
# Out:
# b'<!doctype html> <!--[if lt IE 7]><html lang="en" dir="ltr" class="no-js lt-ie9 lt-ie8 lt-ie7  "><![endif]--> <!--[if IE 7]><html lang="en" dir="ltr" class="no-js lt-ie9 lt-ie8  "><![endif]--> <!--[if IE 8]><html lang="en" dir="ltr" class="no-js lt-ie9  "><![endif]--> <!--[if IE 9]><html lang="en" dir="ltr" class="no-js ie9  "><![endif]--> <!--[if gt IE 8]><!--><html lang="en" dir="ltr" class="no-js  "><!--<![endif]--> <head> <meta charset="utf8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"> <meta name="HandheldFriendly" content="true" />             <link rel="preload" href="//www.dubicars.com/images/384df8/400x234/al-salama-motors/0863f0d2-614c-46bc-ace5-d7e0806312de.jpg" as="image" fetchpriority="high">\n    \n    <link rel="preload" href="/css/new-search-critical.css?v=336ec91238cb5dba31cfe52396f5fd2768" as="style"/>\n <title>New and Used cars for sale in
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.content)

# %%
mains = soup.findAll("div", {"class" : "main"})
# Out:
# <ipython-input-113-530ee753c669>:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   mains = soup.findAll("div", {"class" : "main"})

# %%
len(mains)
# Out:
# 2

# %%
mains[0]
# Out:
# <div class="main">
# <section data-item-hash="search" id="serp-list">
# <ul data-items-key="search" data-sp-block='{"e":"imp","b":"serp-list","p":"search","i":null}'>
# ...

# %%
cars = mains[0].find_all(recursive=False)[0].find_all(recursive=False)[0].find_all(recursive=False)

# %%
len(cars)
# Out:
# 36

# %%
def has_bad_attrs(element):
  bad_ids = ['app-promotion', 'ad-intersect']
  for id in bad_ids:
    if ('id' in element.attrs and id in element['id']):
      return True

  bad_classes = ['serp-banner', 'serp-teads', 'advergic']
  for cl in bad_classes:
    if (cl in element['class']):
      return True
  return False

_counter = 0
for car in cars:
  print(_counter)
  _counter+=1
  print(has_bad_attrs(car))
  print()

cars = [car for car in cars if
        not has_bad_attrs(car)]
# Out:
# 0
# False
#
# 1
# False
#
# 2
# False
#
# 3
# False
#
# 4
# False
#
# 5
# False
#
# 6
# False
#
# 7
# True
#
# 8
# False
#
# 9
# False
#
# 10
# False
#
# 11
# False
#
# 12
# True
#
# 13
# False
#
# 14
# False
#
# 15
# True
#
# 16
# True
#
# 17
# False
#
# 18
# False
#
# 19
# False
#
# 20
# False
#
# 21
# True
#
# 22
# False
#
# 23
# False
#
# 24
# False
#
# 25
# False
#
# 26
# True
#
# 27
# False
#
# 28
# False
#
# 29
# False
#
# 30
# False
#
# 31
# False
#
# 32
# False
#
# 33
# False
#
# 34
# False
#
# 35
# False

# %%
cars[0]
# Out:
# <li class="serp-list-item bg-white premium" data-ga4-detail='{"item_id":740792,"seller_type":"Dealer","price":155000,"export_status":"can_be_exported","export_price":0,"feature_type":"Premium","car_year":2018,"warranty":1,"steering_side":"Left hand","promoted":false,"dealer_site":false,"image_url":"https:\/\/dubicars.com\/images\/95a489\/w_1300x760\/al-salama-motors\/0863f0d2-614c-46bc-ace5-d7e0806312de.jpg","car_make":"BMW","car_model":"X5","body_type":"SUV\/Crossover","condition":"Used","fuel_type":"Gasoline","regional_specs":"GCC","seller_name":"Al Salama Motors"}' data-item-id="740792" data-item-kilometers="112,000 km" data-item-title="BMW X5 XDrive 50i. M Kit" data-message="" data-mixpanel-detail='{"item_id":740792,"financing":true,"package_type":"premium","item_location":"Dubai","item_make":"BMW","item_model":"X5","item_year":2018,"item_specs":"GCC","item_condition":"used","item_exterior_color":"Silver","item_interior_color":"Tan","item_fuel_type":"Gasoline","item_gearbox":"Aut
# ...

# %%
cars[0]['data-ga4-detail']
# Out:
# '{"item_id":740792,"seller_type":"Dealer","price":155000,"export_status":"can_be_exported","export_price":0,"feature_type":"Premium","car_year":2018,"warranty":1,"steering_side":"Left hand","promoted":false,"dealer_site":false,"image_url":"https:\\/\\/dubicars.com\\/images\\/95a489\\/w_1300x760\\/al-salama-motors\\/0863f0d2-614c-46bc-ace5-d7e0806312de.jpg","car_make":"BMW","car_model":"X5","body_type":"SUV\\/Crossover","condition":"Used","fuel_type":"Gasoline","regional_specs":"GCC","seller_name":"Al Salama Motors"}'

# %%
import json

jsoned = json.loads(cars[0]['data-ga4-detail'])

# %%
jsoned
# Out:
# {'item_id': 740792,
#  'seller_type': 'Dealer',
#  'price': 155000,
#  'export_status': 'can_be_exported',
#  'export_price': 0,
#  'feature_type': 'Premium',
#  'car_year': 2018,
#  'warranty': 1,
#  'steering_side': 'Left hand',
#  'promoted': False,
#  'dealer_site': False,
#  'image_url': 'https://dubicars.com/images/95a489/w_1300x760/al-salama-motors/0863f0d2-614c-46bc-ace5-d7e0806312de.jpg',
#  'car_make': 'BMW',
#  'car_model': 'X5',
#  'body_type': 'SUV/Crossover',
#  'condition': 'Used',
#  'fuel_type': 'Gasoline',
#  'regional_specs': 'GCC',
#  'seller_name': 'Al Salama Motors'}

# %%
for car in cars:
  print(car.attrs)
  print(json.loads(car['data-ga4-detail']))

cars_jsoned = [json.loads(car['data-ga4-detail']) for car in cars]
# Out:
# {'class': ['serp-list-item', 'bg-white', 'premium'], 'data-sp-item': '{"pr":165000,"bd":100,"prmtd":false,"lid":758,"gcc":true,"lu":"unique","pid":3,"fin":false,"imp":false,"sid":2183,"sc":false,"md":179,"id":740792,"mk":13,"new":false,"st":"dealer","km":112000,"or":false,"f":false,"prm":true,"version":"1-1-1","bstd":true,"ex":false,"rpr":155000,"pnr":false,"av":null,"v":false,"w":52,"y":2018,"rl":false,"did":730}', 'data-item-id': '740792', 'data-item-title': 'BMW X5 XDrive 50i. M Kit', 'data-item-kilometers': '112,000 km', 'data-message': '', 'data-sp-item-extra': '{"pos": 0}', 'data-sp-click': '{"e":"click"}', 'data-track': '{"ev": "ItemClick", "spData": "sp-click"}', 'data-ga4-detail': '{"item_id":740792,"seller_type":"Dealer","price":155000,"export_status":"can_be_exported","export_price":0,"feature_type":"Premium","car_year":2018,"warranty":1,"steering_side":"Left hand","promoted":false,"dealer_site":false,"image_url":"https:\\/\\/dubicars.com\\/images\\/95a489\\/w_1300x760\\/a
# ...

# %%
cars_jsoned
# Out:
# [{'item_id': 740792,
#   'seller_type': 'Dealer',
#   'price': 155000,
#   'export_status': 'can_be_exported',
#   'export_price': 0,
#   'feature_type': 'Premium',
#   'car_year': 2018,
#   'warranty': 1,
#   'steering_side': 'Left hand',
#   'promoted': False,
#   'dealer_site': False,
#   'image_url': 'https://dubicars.com/images/95a489/w_1300x760/al-salama-motors/0863f0d2-614c-46bc-ace5-d7e0806312de.jpg',
#   'car_make': 'BMW',
#   'car_model': 'X5',
#   'body_type': 'SUV/Crossover',
#   'condition': 'Used',
#   'fuel_type': 'Gasoline',
#   'regional_specs': 'GCC',
#   'seller_name': 'Al Salama Motors'},
#  {'item_id': 836233,
#   'seller_type': 'Private',
#   'price': 220000,
#   'export_status': 'can_be_exported',
#   'export_price': 59945,
#   'feature_type': 'Premium',
#   'car_year': 2021,
#   'warranty': 0,
#   'steering_side': 'Left hand',
#   'promoted': False,
#   'dealer_site': False,
# ...

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
[car_param for car_param in cars_jsoned[0].keys()]
# Out:
# ['item_id',
#  'seller_type',
#  'price',
#  'export_status',
#  'export_price',
#  'feature_type',
#  'car_year',
#  'warranty',
#  'steering_side',
#  'promoted',
#  'dealer_site',
#  'image_url',
#  'car_make',
#  'car_model',
#  'body_type',
#  'condition',
#  'fuel_type',
#  'regional_specs',
#  'seller_name']

# %%
ds = pd.DataFrame(columns =['1'], index=[car_param_name for car_param_name in cars_jsoned[0].keys()])
for car in cars_jsoned:
  ds[car['car_make'] + '_' + car['car_model']] = [car_param for car_param in car.values()]
display(ds)
# Out:
#                   1                                             BMW_X5  \
# item_id         NaN                                             830497
# seller_type     NaN                                             Dealer
# price           NaN                                             345000
# export_status   NaN                                    can_be_exported
# export_price    NaN                                              94500
# feature_type    NaN                                            Premium
# car_year        NaN                                               2022
# warranty        NaN                                                  1
# steering_side   NaN                                          Left hand
# promoted        NaN                                              False
# dealer_site     NaN                                              False
# image_url       NaN  https://dubicars.com/images/b4f1db/w_1300x760/...
# ...
